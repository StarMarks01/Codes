# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as mp
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv(r"C:\Users\Yagnesh Narola\Documents\Coding Languages\Artificial Intelegence\Excel_and_CSV\hotel bookings decision tree.csv")

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df['is_canceled'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.shape
# Out:
# (119390, 32)

# %%
df = df.drop(columns = ['company','reservation_status', 'reservation_status_date','country','agent'])

# %%
# df['country'] = df['country'].astype(str)
# df['country'] = df['country'].replace('NaN',None)
# df['country'] = df['country'].fillna(df['country'].mode()[0])
# type(df['country'])
# df['country']

# %%
df['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %%
df['children'] = pd.to_numeric(df['children'],errors = 'coerce')

# %%
df['children'] = df['children'].fillna(df['children'].median())

# %%
le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
catcol = ['hotel', 'arrival_date_month', 'meal', 
                       'market_segment', 'distribution_channel', 
                       'reserved_room_type', 'assigned_room_type', 
                       'deposit_type', 'customer_type']

# %%
for i in df[catcol]:
    df[i] = le.fit_transform(df[i])

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# ...

# %%
df = df.drop(columns = catcol)

# %%
df = pd.concat([df.reset_index(drop=True),encoded_df.reset_index(drop=True)],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = pd.concat([df.reset_index(drop=True),encoded_df.reset_index(drop=True)],axis = 1)
#
# NameError: name 'encoded_df' is not defined

# %%
model = tree.DecisionTreeClassifier()

# %%
x = df.drop(columns = 'is_canceled')
y = df['is_canceled']

# %%
y.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
model = DecisionTreeClassifier(criterion = "entropy", random_state = 42)
model
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
pred = model.predict(x_test)
pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[434], line 1
# ----> 1 pred = model.predict(x_test)
#       2 pred
#
# File d:\Application Programs\Anaconda\Lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
#     528 check_is_fitted(self)
# --> 529 X = self._validate_X_predict(X, check_input)
#     530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#
# File d:\Application Programs\Anaconda\Lib\site-packages\sklearn\tree\_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     force_all_finite = True
# ...

# %%
model.score(xtest,ytest)
# Out:
# 0.8352039534299355

# %%
classification_report(ytest, pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.87      0.87      0.87     14907\n           1       0.78      0.78      0.78      8971\n\n    accuracy                           0.84     23878\n   macro avg       0.82      0.82      0.82     23878\nweighted avg       0.84      0.84      0.84     23878\n'

# %%
test_data = df.drop('is_canceled')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[386], line 1
# ----> 1 test_data = df.drop('is_canceled')
#
# File d:\Application Programs\Anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
test_data
# Out:
#    lead_time  arrival_date_year  arrival_date_week_number  \
# 0        342               2015                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
#
#    adults  children  babies  is_repeated_guest  previous_cancellations  \
# 0       2       0.0       0                  0                       0
#
#    previous_bookings_not_canceled  booking_changes  agent  \
# 0                               0                3   14.0
#
#    days_in_waiting_list  adr  required_car_parking_spaces  \
# 0                     0  0.0                            0
#
#    total_of_special_requests  hotel_0  hotel_1  arrival_date_month_0  \
# 0                          0      0.0      1.0                   0.0
#
#    arrival_date_month_1  arrival_date_month_2  arrival_date_month_3  \
# 0                   0.0                   0.0                   0.0
#
# ...

# %%
pred = model.predict(test_data)
pred
# Out:
# array([1], dtype=int64)

# %%
inv = le.inverse_transform(pred)
print("Prediction Booking Canceled?:",inv[0])
# Out:
# Prediction Booking Canceled?: Group

# %%
inv
# Out:
# array(['Group'], dtype=object)
