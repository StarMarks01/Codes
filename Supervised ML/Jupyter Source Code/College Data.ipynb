# %%
import pandas as pd
import matplotlib.pyplot as mp
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv(r"C:\Users\Pavilion\Documents\Coding Languages\Artificial Intelligence\Excel and Csv\College Data.csv")

# %%
df2 = df.copy()
scaler = StandardScaler()
PrivateLE = LabelEncoder()
kmeans  = KMeans(n_clusters = 3)

# %%
df2.isnull().sum()
# Out:
# College        0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %%
df2
# Out:
#                             College Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
df2['Private'] = PrivateLE.fit_transform(df2['Private'])

# %%
df2
# Out:
#                             College  Private   Apps  Accept  Enroll  \
# 0      Abilene Christian University        1   1660    1232     721
# 1                Adelphi University        1   2186    1924     512
# 2                    Adrian College        1   1428    1097     336
# 3               Agnes Scott College        1    417     349     137
# 4         Alaska Pacific University        1    193     146      55
# ..                              ...      ...    ...     ...     ...
# 772         Worcester State College        0   2197    1515     543
# 773               Xavier University        1   1959    1805     695
# 774  Xavier University of Louisiana        1   2097    1915     695
# 775                 Yale University        1  10705    2453    1317
# 776    York College of Pennsylvania        1   2989    1855     691
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# 0           23         52         2885          537      7440        3300
# ...

# %%
df2 = df2.drop(columns = ['College'])

# %%
df2
# Out:
#      Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0          1   1660    1232     721         23         52         2885
# 1          1   2186    1924     512         16         29         2683
# 2          1   1428    1097     336         22         50         1036
# 3          1    417     349     137         60         89          510
# 4          1    193     146      55         16         44          249
# ..       ...    ...     ...     ...        ...        ...          ...
# 772        0   2197    1515     543          4         26         3089
# 773        1   1959    1805     695         24         47         2849
# 774        1   2097    1915     695         34         61         2793
# 775        1  10705    2453    1317         95         99         5217
# 776        1   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
x = df2.copy()

# %%
Scaled = scaler.fit_transform(x)

# %%
df2['Cluster'] = kmeans.fit_predict(Scaled)

# %%
df2
# Out:
#      Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0          1   1660    1232     721         23         52         2885
# 1          1   2186    1924     512         16         29         2683
# 2          1   1428    1097     336         22         50         1036
# 3          1    417     349     137         60         89          510
# 4          1    193     146      55         16         44          249
# ..       ...    ...     ...     ...        ...        ...          ...
# 772        0   2197    1515     543          4         26         3089
# 773        1   1959    1805     695         24         47         2849
# 774        1   2097    1915     695         34         61         2793
# 775        1  10705    2453    1317         95         99         5217
# 776        1   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
df2['Cluster'].value_counts()
# Out:
# Cluster
# 1    407
# 2    251
# 0    119
# Name: count, dtype: int64
