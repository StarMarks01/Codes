# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mp
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('quikr_car.csv')

# %%
df.shape
# Out:
# (892, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df = df[df['year'].str.isnumeric()]

# %%
df['year'] = df['year'].astype(int)

# %%
df['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 842 entries, 0 to 891
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 842 non-null    int64
# dtypes: int64(1)
# memory usage: 13.2 KB

# %%
df['year'].astype(int)
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 886    2009
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 842, dtype: int64

# %%
df = df[df['Price']!='Ask For Price']

# %%
df['Price'] = df['Price'].str.replace(',','')

# %%
df['Price'] = df['Price'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.8+ KB

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
x = df[['name', 'company', 'year','kms_driven', 'fuel_type']]
y = df['Price']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=34)

# %%
df['kms_driven'] = df['kms_driven'].str.split().str.get(0).str.replace(',','')
df
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#     kms_driven fuel_type
# 0        45000    Petrol
# 1           40    Diesel
# 3        28000    Petrol
# 4        36000    Diesel
# ...

# %%
df = df[df['kms_driven'].str.isnumeric()]
df['kms_driven'] = df['kms_driven'].astype(int)
df
# Out:
# C:\Users\yagne\AppData\Local\Temp\ipykernel_2592\3274905505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kms_driven'] = df['kms_driven'].astype(int)
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int64
#  3   Price       817 non-null    int64
#  4   kms_driven  817 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 44.7+ KB

# %%
df = df[df['fuel_type'].isna()]

# %%
df['name'].str.split().str.join(' ')
# Out:
# 132    Toyota Corolla
# Name: name, dtype: object

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       1 non-null      int64
#  1   name        1 non-null      object
#  2   company     1 non-null      object
#  3   year        1 non-null      int64
#  4   Price       1 non-null      int64
#  5   kms_driven  1 non-null      int64
#  6   fuel_type   0 non-null      object
# dtypes: int64(4), object(3)
# memory usage: 188.0+ bytes

# %%
one = OneHotEncoder()
one
# Out:
# OneHotEncoder()

# %%
df.columns
# Out:
# Index(['index', 'name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df.to_csv('Cleaned_Car_data.csv')

# %%
x = df[['name', 'company', 'year','kms_driven', 'fuel_type']]
y = ['Price']

# %%
# X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=34)

# %%
one.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
trans_col = make_column_transformer((OneHotEncoder(categories=one.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
reg = LinearRegression()

# %%
pipe = make_pipeline(trans_col,reg)

# %%
ypred = pipe.predict(y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[228], line 1
# ----> 1 ypred = pipe.predict(y_test)
#
# File g:\Programming Languages\Python\Lib\site-packages\sklearn\pipeline.py:600, in Pipeline.predict(self, X, **params)
#     598 if not _routing_enabled():
#     599     for _, name, transform in self._iter(with_final=False):
# --> 600         Xt = transform.transform(Xt)
#     601     return self.steps[-1][1].predict(Xt, **params)
#     603 # metadata routing enabled
#
# File g:\Programming Languages\Python\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
# ...

# %%
r2_score(y_test,ypred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 r2_score(y_test,ypred)
#
# NameError: name 'ypred' is not defined
