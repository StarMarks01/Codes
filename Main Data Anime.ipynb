# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\Yagnesh Narola\Documents\Coding Languages\Artificial Intelligence\Excel and Csv\Main Data Anime.csv")

# %%
df2 = df.copy()
le = LabelEncoder()

# %%
df2.isnull().sum()
# Out:
# title         0
# type          0
# source        0
# score         0
# scored_by     0
# rank          0
# popularity    0
# dtype: int64

# %%
df2 = df2.drop(columns = 'scored_by')

# %%
sns.boxplot(df2['score'])
# Out:
# <Axes: ylabel='score'>

# %%
objvar = df2.select_dtypes(include = 'object')
for i in objvar.columns:
    df2[i] = le.fit_transform(df2[i])

# %%
def Outliers(df,columns):
    for i in columns:
        q1 = df[i].quantile(0.25)
        q3 = df[i].quantile(0.75)
        iqr = q3 - q1
        upperlimit = q3 + (1.5 * iqr)
        lowerlimit = q1 - (1.5 * iqr)
        df.loc[(df[i] > upperlimit), i] = upperlimit
        df.loc[(df[i] < lowerlimit), i] = lowerlimit
    return df
    
df2 = Outliers(df2,['score','rank','popularity'])
# Out:
# C:\Users\Yagnesh Narola\AppData\Local\Temp\ipykernel_1456\866975718.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4183.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[(df[i] > upperlimit), i] = upperlimit

# %%
sns.boxplot(df2['popularity'])
# Out:
# <Axes: ylabel='popularity'>

# %%
Maindf = pd.concat()
