# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r'C:\Users\Yagnesh Narola\Documents\Coding Languages\Artificial Intelligence\AI Work\Artificial-Intelligence\Excel_and_CSV\bangalore house price prediction OHE-data.csv')

# %%
x = df.drop(columns = ['price'])
y = df['price']

# %%
xtrain, xtest, ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
scaler.fit(xtrain)
# Out:
# StandardScaler()

# %%
xtrainscaled = scaler.transform(xtrain)
xtestscaled = scaler.transform(xtest)

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtest,ytest)
# Out:
# 0.9196808132211657

# %%
model.predict(xtest)
# Out:
# array([27.20184313, 52.88038063, 64.11169828, ..., 51.13592971,
#        11.96514123, 34.76431452])

# %%
model.coef_
# Out:
# array([ 2.38536597e+00, -2.80010363e-01,  8.49843396e-02, -1.46622201e+01,
#         2.53937967e-02,  2.40003346e+00, -1.09376347e+00, -1.09920365e+01,
#        -5.45236174e+00, -1.93192832e+01, -1.53621220e+01,  3.40638448e+00,
#        -7.77974421e+00,  1.59175032e+01,  3.54331692e+00, -1.26825637e+01,
#        -2.02857519e+00,  2.07710450e+01, -1.25514467e+01,  1.99353232e+01,
#        -2.67440084e+01, -1.55350188e+01, -7.02768467e+00, -8.12048394e-01,
#         1.17920071e+01,  2.12553564e+01, -5.76624554e+01, -9.82172223e+00,
#        -5.56853112e+00,  2.16231627e+01, -4.08207930e+00, -5.50613592e+00,
#         8.33029140e+00, -1.86063465e+01,  1.62362379e+00, -1.78617487e+01,
#         5.86166309e+00,  9.67437393e+00,  4.63507060e+01,  2.22274822e+00,
#         7.72684887e+00,  4.24386706e+00, -2.73373906e+00,  1.59900237e+01,
#        -2.13153576e+01, -4.13375150e+01, -2.15265219e+00,  6.38168541e-01,
# ...

# %%
model.intercept_
# Out:
# -144.09906082730953

# %%
rd = Ridge()
ls = Lasso()

# %%
ls.fit(xtrain,ytrain)
# Out:
# Lasso()

# %%
ls.score(xtest,ytest)
# Out:
# 0.9039840482349378

# %%
rd.fit(xtrain,ytrain)
rd.score(xtest, ytest)
# Out:
# 0.9195379652632009

# %%
rd = Ridge(alpha = 3)
ls = Lasso(alpha = 3)

# %%
rd.fit(xtrain,ytrain)
rd.score(xtest,ytest)
# Out:
# 0.9191737002075224

# %%
ls.fit(xtrain,ytrain)
ls.score(xtest,ytest)
# Out:
# 0.9017533299894762
