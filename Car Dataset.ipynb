# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
le = LabelEncoder()
model = LinearRegression()
model2 =LinearRegression()
poly = PolynomialFeatures()
scaler = StandardScaler()
dtr = DecisionTreeRegressor()
model3 = LogisticRegression()

# %%
df = pd.read_csv(r'C:\Users\Yagnesh Narola\Documents\Coding Languages\Artificial Intelligence\Excel_and_CSV\cars dataset.csv')

# %%
df
# Out:
#      buying  maint  doors persons lug_boot safety    car
# 0     vhigh  vhigh    two     two    small    low  unacc
# 1     vhigh  vhigh    two     two    small    med  unacc
# 2     vhigh  vhigh    two     two    small   high  unacc
# 3     vhigh  vhigh    two     two      med    low  unacc
# 4     vhigh  vhigh    two     two      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# car         0
# dtype: int64

# %%
for i in df.columns:
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#       buying  maint  doors  persons  lug_boot  safety  car
# 0          3      3      3        2         2       1    2
# 1          3      3      3        2         2       2    2
# 2          3      3      3        2         2       0    2
# 3          3      3      3        2         1       1    2
# 4          3      3      3        2         1       2    2
# ...      ...    ...    ...      ...       ...     ...  ...
# 1723       1      1      0        1         1       2    1
# 1724       1      1      0        1         1       0    3
# 1725       1      1      0        1         0       1    2
# 1726       1      1      0        1         0       2    1
# 1727       1      1      0        1         0       0    3
#
# [1728 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# car         0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
x = df.drop(columns = 'car')
y = df['car']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,random_state = 42,test_size = 0.2)

# %%
scaler.fit(xtrain)
xtrainscaled = scaler.transform(xtrain)
xtestscaled = scaler.transform(xtest)

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtest,ytest)
# Out:
# 0.11913770587603023

# %%
ypred = model.predict(xtest)

# %%
poly.fit(xtrain)
xtrainpoly = poly.transform(xtrain)
xtestpoly = poly.transform(xtest)

# %%
model2.fit(xtrainpoly,ytrain)
# Out:
# LinearRegression()

# %%
model2.score(xtestpoly,ytest)
# Out:
# 0.3116701089633319

# %%
model3.fit(xtrainscaled,ytrain)
# Out:
# LogisticRegression()

# %%
model3.score(xtestscaled,ytest)
# Out:
# 0.708092485549133

# %%
dtr.fit(xtrainscaled,ytrain)
dtr.score(xtestscaled,ytest)
# Out:
# 0.9456544502617801
