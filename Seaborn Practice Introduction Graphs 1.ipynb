# %%
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sns
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('car_crashes')

# %%
mp.scatter(x = df.speeding,y = df.alcohol)

# %%
mp.scatter(df.speeding,df.alcohol)
# sns.set_style('dark')
sns.set_style('ticks')
# sns.set()
sns.despine()
mp.show()
