# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df = pd.read_csv(r"C:\Users\Yagnesh Narola\Documents\Coding Languages\Artificial Intelligence\Excel_and_CSV\Students Performance.csv")

# %%
df2 = df.copy()
df2 = df2.drop(columns = ['race/ethnicity','lunch'])

# %%
df2
# Out:
#      gender parental level of education test preparation course  math score  \
# 0    female           bachelor's degree                    none          72
# 1    female                some college               completed          69
# 2    female             master's degree                    none          90
# 3      male          associate's degree                    none          47
# 4      male                some college                    none          76
# ..      ...                         ...                     ...         ...
# 995  female             master's degree               completed          88
# 996    male                 high school                    none          62
# 997  female                 high school               completed          59
# 998  female                some college               completed          68
# 999  female                some college                    none          77
#
#      reading score  writing score
# ...

# %%
objcols = df2.select_dtypes(include = 'object')
for i in objcols.columns:
    df2[i] = le.fit_transform(df2[i])

# %%
df2
# Out:
#      gender  parental level of education  test preparation course  math score  \
# 0         0                            1                        1          72
# 1         0                            4                        0          69
# 2         0                            3                        1          90
# 3         1                            0                        1          47
# 4         1                            4                        1          76
# ..      ...                          ...                      ...         ...
# 995       0                            3                        0          88
# 996       1                            2                        1          62
# 997       0                            2                        0          59
# 998       0                            4                        0          68
# 999       0                            4                        1          77
#
# ...

# %%
df2['Average'] = df2['math score'] + df2['reading score'] + df2['writing score']/3

# %%
df2
# Out:
#      gender  parental level of education  test preparation course  math score  \
# 0         0                            1                        1          72
# 1         0                            4                        0          69
# 2         0                            3                        1          90
# 3         1                            0                        1          47
# 4         1                            4                        1          76
# ..      ...                          ...                      ...         ...
# 995       0                            3                        0          88
# 996       1                            2                        1          62
# 997       0                            2                        0          59
# 998       0                            4                        0          68
# 999       0                            4                        1          77
#
# ...
